# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from PIL import Image
import cv2
from google.colab.patches import cv2_imshow

# %%
img = mpimg.imread('/content/Dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %% [markdown]
# 360,540 ----> Dimensions
#
# 3--->different channel no.---> red,green,blue

# %%
img.shape
# Out:
# (360, 540, 3)

# %%
img_plot = plt.imshow(img)

# %% [markdown]
# Image Resizing

# %%
img2 = Image.open('/content/Dog.jpg')

# %%
img_resizing = img2.resize((200,200))

# %%
img_plot2 = plt.imshow(img_resizing)

# %% [markdown]
# Converting the image into Grayscale image

# %%
img3 = cv2.imread('/content/Dog.jpg')

# %%
gray_scale_image = cv2.cvtColor(img3,cv2.COLOR_RGB2GRAY)

# %%
cv2_imshow(gray_scale_image)
# Out:
# <PIL.Image.Image image mode=L size=540x360>
