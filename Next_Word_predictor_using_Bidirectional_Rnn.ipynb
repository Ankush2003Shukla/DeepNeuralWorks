Have you been to the new mall yet, heard it's huge?
No, not yet, is it nice, worth checking out?
Yes, lots of shops and a big food court to explore.
We should go sometime, maybe next weekend?
Definitely, let's plan for it, sounds like fun.
How's your pet doing, everything okay with him?
He's good, thanks for asking, still as playful as ever.
Cute as always, how's yours, still causing trouble?
She's doing well, just had a check-up at the vet.
Have you been to the vet recently, all good?
Yes, last week for a check-up, everything's fine.
Everything okay, nothing to worry about?
Yes, all good, just routine stuff.
That's good to hear, glad everything is fine.
Need to go grocery shopping later, running out of stuff.
Same, running out of everything, let's go together.
We should go together, makes it more fun.
Sounds good, let's make a list of what we need.
Good idea, what's on your list, anything special?
Just the usual stuff, nothing out of the ordinary.
Same here, just the essentials and a few treats.
Did you try that new recipe I sent you last week?
Yes, it was delicious, everyone loved it.
Glad you liked it, any tips for improvement?
Just follow the instructions, it's pretty straightforward.
Will do, thanks for sharing, always up for new recipes.
Thanks! No problem, happy to share.
Are you coming to the party next week, should be fun?
Yes, wouldn't miss it for anything, looking forward to it.
Great, it's going to be fun, lots of people coming.
Looking forward to it, should be a good time.
Me too, always a blast at these gatherings.
How's your car running, any issues lately?
Good, just got it serviced last week, running smooth.
That's good, need to do mine soon, overdue for a check-up.
Don't forget, it's important to keep it maintained.
Definitely, will schedule an appointment soon.
By the way, have you heard from our old friend lately?
Yes, we chatted last week, he's doing well.
How's he doing, any big news from his side?
He's good, moved to a new city for a new job.
Wow, that's big news, hope he likes it there.
Yes, he's excited, new opportunities and all.
Good for him, we should visit sometime, catch up.
Agreed, let's plan a trip soon, would be nice to see him.
Hey, do you have any plans for lunch today, want to meet up?
Not yet, why, do you have something in mind?
Want to grab something together, maybe try a new place?
Sure, where do you want to go, any suggestions?
How about the new cafe down the street, heard good things?
Sounds good, let's meet at 1 PM, does that work?
See you then, looking forward to catching up.
Don't forget your umbrella, looks like it might rain later.
Thanks for the reminder, weather's been unpredictable.
No problem, better to be prepared than get soaked.
Talk later, take care until then.
"""

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts([faqs])

# %%
tokenizer.word_index
# Out:
# {'to': 1,
#  'the': 2,
#  'it': 3,
#  'you': 4,
#  'a': 5,
#  'for': 6,
#  'good': 7,
#  'new': 8,
#  "it's": 9,
#  'do': 10,
#  "let's": 11,
#  'about': 12,
#  'any': 13,
#  'that': 14,
#  'up': 15,
#  'have': 16,
#  'did': 17,
#  'i': 18,
#  'at': 19,
#  'just': 20,
#  'yes': 21,
#  'is': 22,
#  'and': 23,
#  'sounds': 24,
#  'of': 25,
#  'be': 26,
#  'last': 27,
#  'what': 28,
#  'in': 29,
#  'we': 30,
#  'should': 31,
#  'thanks': 32,
#  'me': 33,
#  'need': 34,
#  'later': 35,
#  'yet': 36,
#  'go': 37,
#  'looking': 38,
#  "how's": 39,
#  'your': 40,
#  'doing': 41,
#  'always': 42,
#  'anything': 43,
#  'next': 44,
#  'see': 45,
#  'was': 46,
#  'this': 47,
#  'great': 48,
#  'out': 49,
#  'been': 50,
#  'everything': 51,
#  'too': 52,
#  'with': 53,
#  'going': 54,
#  'week': 55,
#  'fun': 56,
#  'how': 57,
#  'all': 58,
#  'are': 59,
#  'stuff': 60,
#  'want': 61,
#  'get': 62,
#  'not': 63,
#  'heard': 64,
#  'soon': 65,
#  'like': 66,
#  'plan': 67,
#  'forward': 68,
# ...

# %%
len(tokenizer.word_index)
# Out:
# 408

# %%
input_sequences = []
for sentence in faqs.split('\n'):
  tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]

  for i in range(1,len(tokenized_sentence)):
    input_sequences.append(tokenized_sentence[:i+1])

# %%
input_sequences
# Out:
# [[101, 17],
#  [101, 17, 4],
#  [101, 17, 4, 45],
#  [101, 17, 4, 45, 2],
#  [101, 17, 4, 45, 2, 8],
#  [101, 17, 4, 45, 2, 8, 208],
#  [101, 17, 4, 45, 2, 8, 208, 27],
#  [101, 17, 4, 45, 2, 8, 208, 27, 209],
#  [18, 102],
#  [18, 102, 210],
#  [18, 102, 210, 57],
#  [18, 102, 210, 57, 3],
#  [18, 102, 210, 57, 3, 211],
#  [18, 102, 210, 57, 3, 211, 3],
#  [18, 102, 210, 57, 3, 211, 3, 46],
#  [18, 102, 210, 57, 3, 211, 3, 46, 212],
#  [136, 3],
#  [136, 3, 46],
#  [136, 3, 46, 137],
#  [136, 3, 46, 137, 103],
#  [136, 3, 46, 137, 103, 138],
#  [136, 3, 46, 137, 103, 138, 213],
#  [136, 3, 46, 137, 103, 138, 213, 214],
#  [136, 3, 46, 137, 103, 138, 213, 214, 104],
#  [138, 215],
#  [138, 215, 18],
#  [138, 215, 18, 216],
#  [138, 215, 18, 216, 45],
#  [138, 215, 18, 216, 45, 14],
#  [138, 215, 18, 216, 45, 14, 105],
#  [138, 215, 18, 216, 45, 14, 105, 19],
#  [138, 215, 18, 216, 45, 14, 105, 19, 58],
#  [28, 59],
#  [28, 59, 4],
#  [28, 59, 4, 15],
#  [28, 59, 4, 15, 1],
# ...

# %%
max_len = max([len(x) for x in input_sequences])

# %%
print(max_len)
# Out:
# 13

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_sequences = pad_sequences(input_sequences,maxlen = max_len,padding = "pre")

# %%
padded_input_sequences
# Out:
# array([[  0,   0,   0, ...,   0, 101,  17],
#        [  0,   0,   0, ..., 101,  17,   4],
#        [  0,   0,   0, ...,  17,   4,  45],
#        ...,
#        [  0,   0,   0, ...,  35, 406, 407],
#        [  0,   0,   0, ..., 406, 407, 408],
#        [  0,   0,   0, ..., 407, 408,  82]], dtype=int32)

# %%
x = padded_input_sequences[:,:-1]

# %%
y = padded_input_sequences[:,-1]

# %%
y
# Out:
# array([ 17,   4,  45, ..., 407, 408,  82], dtype=int32)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, num_classes = 409)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,LSTM,Dense,Bidirectional,Dropout

# %%
model1 = Sequential()
model1.add(Embedding(283,100,input_length=12))
model1.add(Bidirectional(LSTM(150)))
model1.add(Dense(409, activation='softmax'))

# %%
model1.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model1.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_2 (Embedding)     (None, 12, 100)           28300
#
#  bidirectional_2 (Bidirecti  (None, 300)               301200
#  onal)
#
#  dense_2 (Dense)             (None, 409)               123109
#
# ...
# Total params: 452609 (1.73 MB)
# Trainable params: 452609 (1.73 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model1.fit(x,y,epochs=100)
# Out:
# Epoch 1/100
# 37/37 [==============================] - 1s 30ms/step - loss: 5.5021 - accuracy: 0.0372
# Epoch 2/100
# 37/37 [==============================] - 1s 24ms/step - loss: 5.3787 - accuracy: 0.0484
# Epoch 3/100
# 37/37 [==============================] - 1s 15ms/step - loss: 5.2821 - accuracy: 0.0441
# Epoch 4/100
# 37/37 [==============================] - 1s 14ms/step - loss: 5.1732 - accuracy: 0.0433
# Epoch 5/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.0620 - accuracy: 0.0493
# Epoch 6/100
# 37/37 [==============================] - 0s 10ms/step - loss: 4.9724 - accuracy: 0.0649
# Epoch 7/100
# 37/37 [==============================] - 1s 15ms/step - loss: 4.8558 - accuracy: 0.0683
# Epoch 8/100
# 37/37 [==============================] - 0s 7ms/step - loss: 4.7520 - accuracy: 0.0666
# Epoch 9/100
# 37/37 [==============================] - 0s 12ms/step - loss: 4.6343 - accuracy: 0.0787
# Epoch 10/100
# ...

# %%
import numpy as np
import time

# %%
text = "Awesome"

for i in range(10):
  #tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  #padding
  padded_token_text = pad_sequences([token_text],maxlen=12, padding='pre')
  #predict
  pos = np.argmax(model1.predict(padded_token_text))

  for word,index in  tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
# Out:
# 1/1 [==============================] - 1s 691ms/step
# Awesome doing
# 1/1 [==============================] - 0s 19ms/step
# Awesome doing well
# 1/1 [==============================] - 0s 18ms/step
# Awesome doing well just
# 1/1 [==============================] - 0s 25ms/step
# Awesome doing well just had
# 1/1 [==============================] - 0s 18ms/step
# Awesome doing well just had a
# 1/1 [==============================] - 0s 18ms/step
# Awesome doing well just had a check
# 1/1 [==============================] - 0s 20ms/step
# Awesome doing well just had a check up
# 1/1 [==============================] - 0s 18ms/step
# Awesome doing well just had a check up at
# 1/1 [==============================] - 0s 18ms/step
# Awesome doing well just had a check up at the
# 1/1 [==============================] - 0s 18ms/step
# Awesome doing well just had a check up at the vet

# %%
text = "By the way"

for i in range(10):
  #tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  #padding
  padded_token_text = pad_sequences([token_text],maxlen=12, padding='pre')
  #predict
  pos = np.argmax(model1.predict(padded_token_text))

  for word,index in  tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# By the way have
# 1/1 [==============================] - 0s 18ms/step
# By the way have you
# 1/1 [==============================] - 0s 18ms/step
# By the way have you heard
# 1/1 [==============================] - 0s 17ms/step
# By the way have you heard from
# 1/1 [==============================] - 0s 27ms/step
# By the way have you heard from our
# 1/1 [==============================] - 0s 18ms/step
# By the way have you heard from our old
# 1/1 [==============================] - 0s 19ms/step
# By the way have you heard from our old friend
# 1/1 [==============================] - 0s 19ms/step
# By the way have you heard from our old friend lately
# 1/1 [==============================] - 0s 19ms/step
# By the way have you heard from our old friend lately lately
# 1/1 [==============================] - 0s 18ms/step
# By the way have you heard from our old friend lately lately our

# %%
text = "Do you miss"

for i in range(10):
  #tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  #padding
  padded_token_text = pad_sequences([token_text],maxlen=12, padding='pre')
  #predict
  pos = np.argmax(model1.predict(padded_token_text))

  for word,index in  tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
# Out:
# 1/1 [==============================] - 0s 34ms/step
# Do you miss the
# 1/1 [==============================] - 0s 19ms/step
# Do you miss the old
# 1/1 [==============================] - 0s 19ms/step
# Do you miss the old place
# 1/1 [==============================] - 0s 19ms/step
# Do you miss the old place the
# 1/1 [==============================] - 0s 19ms/step
# Do you miss the old place the people
# 1/1 [==============================] - 0s 30ms/step
# Do you miss the old place the people there
# 1/1 [==============================] - 0s 19ms/step
# Do you miss the old place the people there people
# 1/1 [==============================] - 0s 20ms/step
# Do you miss the old place the people there people huge
# 1/1 [==============================] - 0s 19ms/step
# Do you miss the old place the people there people huge huge
# 1/1 [==============================] - 0s 19ms/step
# Do you miss the old place the people there people huge huge huge

# %%
model1.save_weights("Model.h5")
